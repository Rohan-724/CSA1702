# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohan-724/CSA1702/blob/main/Lab/EXP_27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('% Prolog Program for a database with Name and Date of Birth\n')
print('% Predicate: person(Name, DateOfBirth)\n')
print('person(john_doe, date(1990, 5, 15)).')
print('person(jane_smith, date(1988, 11, 22)).')
print('person(peter_jones, date(1992, 3, 10)).')
print('person(alice_white, date(1995, 8, 30)).')
print('\n% Example queries:')
print('% To find all people and their DOBs:')
print('% ?- person(Name, DOB).')
print('\n% To find people born after a certain year (e.g., 1990):')
print('% ?- person(Name, date(Year, _, _)), Year > 1990.')
print('\n% To find people born in a specific month (e.g., May):')
print('% ?- person(Name, date(_, 5, _)).')
# Out:
# % Prolog Program for a database with Name and Date of Birth
#
# % Predicate: person(Name, DateOfBirth)
#
# person(john_doe, date(1990, 5, 15)).
# person(jane_smith, date(1988, 11, 22)).
# person(peter_jones, date(1992, 3, 10)).
# person(alice_white, date(1995, 8, 30)).
#
# % Example queries:
# % To find all people and their DOBs:
# % ?- person(Name, DOB).
#
# % To find people born after a certain year (e.g., 1990):
# % ?- person(Name, date(Year, _, _)), Year > 1990.
#
# % To find people born in a specific month (e.g., May):
# % ?- person(Name, date(_, 5, _)).
