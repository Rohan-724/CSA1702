# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohan-724/CSA1702/blob/main/Lab/Exp_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import string

def remove_punctuations(text):
    """Removes punctuations from a given string."""
    translator = str.maketrans('', '', string.punctuation)
    return text.translate(translator)

# Example usage:
input_string = "Hello, World! How are you doing today?"
cleaned_string = remove_punctuations(input_string)
print(f"Original string: {input_string}")
print(f"Cleaned string: {cleaned_string}")
