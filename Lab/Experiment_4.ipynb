# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohan-724/CSA1702/blob/main/Lab/Experiment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def sort_sentence_alphabetically(sentence):
    words = sentence.split()
    words.sort()
    return ' '.join(words)

# Example usage:
sentence = "This is an example sentence to be sorted"
sorted_sentence = sort_sentence_alphabetically(sentence)
print(f"Original sentence: {sentence}")
print(f"Sorted sentence: {sorted_sentence}")
