# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohan-724/CSA1702/blob/main/Neighbor_Values.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Neighbor values (higher is better)

neighbors = {
    'A': 10,
    'B': 25,
    'C': 18,
    'D': 30
}

print("Neighbor Values:")

for node in neighbors:
    print(node, ":", neighbors[node])

best = max(neighbors, key=neighbors.get)

print("\nMove to:", best gillc linbing
